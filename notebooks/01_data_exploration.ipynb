# %% [markdown]
# # 01 - Exploration des Données
#
# Ce notebook explore les datasets CarDD et Stanford Cars:
# - Visualisation des images
# - Distribution des classes
# - Statistiques des images (taille, résolution)
# - Qualité des données

# %%
# TODO: Implémenter l'exploration des données
