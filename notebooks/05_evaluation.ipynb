# %% [markdown]
# # 05 - Évaluation et Comparaison des Modèles
#
# Ce notebook évalue et compare les modèles:
# - Chargement des meilleurs checkpoints
# - Évaluation sur le test set
# - Calcul des métriques (Accuracy, Precision, Recall, F1)
# - Matrices de confusion
# - Comparaison Model A vs Model B

# %%
# TODO: Implémenter l'évaluation et la comparaison
