# %% [markdown]
# # 04 - Entraînement Model B (Deep CNN avec Skip Connections)
#
# Ce notebook entraîne le Model B:
# - Configuration et hyperparamètres
# - Architecture DeepCNN avec ResidualBlocks
# - Boucle d'entraînement
# - Suivi des métriques
# - Sauvegarde du meilleur modèle

# %%
# TODO: Implémenter l'entraînement du Model B
