# %% [markdown]
# # 03 - Entraînement Model A (Baseline VGG-like)
#
# Ce notebook entraîne le Model A:
# - Configuration et hyperparamètres
# - Architecture BaselineCNN
# - Boucle d'entraînement
# - Suivi des métriques
# - Sauvegarde du meilleur modèle

# %%
# TODO: Implémenter l'entraînement du Model A
