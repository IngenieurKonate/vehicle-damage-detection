# %% [markdown]
# # 02 - Pipeline de Prétraitement
#
# Ce notebook implémente le prétraitement des données:
# - Combinaison des datasets CarDD et Stanford Cars
# - Échantillonnage et équilibrage des classes
# - Split train/val/test stratifié
# - Création de la structure processed/

# %%
# TODO: Implémenter le pipeline de prétraitement
